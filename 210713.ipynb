# %% [markdown]
# <a href="https://colab.research.google.com/github/yun-aha/GSTEC/blob/main/210713.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 빅데이터분석

# %% [markdown]
# ### Jupyter Notebook 과 구글 Colab사용법
# * Jupyter 노트북
#   - 원래는 IPython Notebook 이었다가 V3.0 이후로는 Jupyter Notebook으로 파생.
#   - 대화형 연산 공책.
#   - Jupyter Notebook은 Python 이외에도 Julia, R, Haskell, Ruby 등 지원.
#   - Anaconda에 포함되어 설치된다.
#
# * Jupyter 노트북의 특장점
#   - 함수 자동 완성 기능.
#   - 셀 단위의 순차적 실행.
#   - 마크다운, HTML, LaTex 및 JavaScript 지원.
#   - edit모드와 command모드가 따로 있다.

# %% [markdown]
# * 구글 Colab
#   - 구글 Colab은 브라우저에서 Python을 작성하고 실행할 수 있다.
#     * Jupyter notebook과 유사한 노트북 환경 제공.
#   - 구글 Colab에는 다음과 같은 장점이 있다.
#     * GPU/TPU를 무료로 사용할 수 있다.
#     * 많은 라이브러리가 설치되어 있다.
#     * 구글 드라이브, Git, GitHub, 등과 연동 용이.
# * 구글 Colab 노트북을 사용하는 방법:
#   - 메뉴에서 런타임 → 런타임 유형 변경 으로 들어가서 하드웨어 가속기를 선택할 수 있다 (예: GPU).
#   - 상단에 있는 “[+] 코드” 또는 “[+] 텍스트”를 클릭해서 해당 유형의 셀을 삽입할 수 있다.
#   - 주요 메뉴 기능을 다음과 같이 Jupyter Notebook과 비교해 볼 수 있다.
#   -Jupyter 노트북과 다르게 Colab에는 Command모드와 Edit모드가 구별되지 않는다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 데이터 불러오기
from google.colab import files
my_dict = files.upload()
# Out:
#      <input type="file" id="files-dc2e6e36-4ef4-46ae-9a8d-d11c9651f8dc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc2e6e36-4ef4-46ae-9a8d-d11c9651f8dc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data_studentlist_en.csv to data_studentlist_en.csv

# %% [markdown]
# ### $$ 마크다운 $$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# %ls
# Out:
# data_credit.csv  data_studentlist_en.csv  sample_data/

# %%
# %pwd
# Out:
# '/content'

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.5 LTS

# %%
# %rerun
# Out:
# === Executing: ===
# !cat /etc/issue.net
# === Output: ===
# Ubuntu 18.04.5 LTS

# %% [markdown]
# # 2.

# %% [markdown]
# ### 프로젝트 계획서 작성
# 아트닝 대표

# %% [markdown]
# # 3.

# %%
#class based view < . > function based view

# %% [markdown]
# # 4. 알고리즘

# %%
# append, len, remove 없이 풀이 해설
class Stack:
    def __init__(self, n):
        self.stack = [None for _ in range(n)]
        self.stack_size = 0

    def push(self, num):
        self.stack[self.stack_size] = int(num)
        self.stack_size += 1

    def pop(self):
      last_val = self.top()
      if last_val > 0:
        self.stack_size -=1
      return last_val

    def size(self):
        return self.stack_size

    def empty(self):
        if self.stack_size > 0:
            return 0
        return 1

    def top(self):
        if self.stack_size > 0:
            return self.stack[self.stack_size-1]
        
        return -1

# %%
def run_cmd_with_stack(my_stack, cmd):
    cmd_type = cmd[0]
    if cmd_type == "push":
        _, num = cmd    # num = cmd[1]
        my_stack.push(num)
    elif cmd_type == "pop":
        print(my_stack.pop())
    elif cmd_type == "size":
        print(my_stack.size())
    elif cmd_type == "empty":
        print(my_stack.empty())
    elif cmd_type == "top":
        print(my_stack.top())
    return my_stack

n = int(input())
my_stack = Stack(n)

for _ in range(n):
    # "push 2".split() => ["push", "2"]
    # "size".split() => ["size"]
    command = input().split()
    my_stack = run_cmd_with_stack(my_stack, command)
# print(stack)
# Out:
# 5
# push 23
# size
# 1
# push 34
# top
# 34
# empty
# 0

# %% [markdown]
# ### 큐
# FIFO(First In First Out)

# %% [markdown]
# Q. 큐문제 : 정수를 저장하는 큐를 구현한 다음, 입력으로 주어지는 명령을 처리하는 프로그램을 작성하시오.
# * push X : 정수 X를 큐에 넣는 연산이다.
# * pop : 큐에서 가장 앞에 있는 정수를 빼고, 그 수를 출력한다. 만약 큐에 들어있는 정수가 없는 경우엔 -1을 출력
# * size : 큐에 들어있는 정수의 개수를 출력한다.
# * empty : 큐가 비어있으면 1, 아니면 0을 출력한다.
# * front : 큐의 가장 앞에 있는 정수를 출력한다. 만약 큐에 들어있는 정수가 없는 경우엔 -1을 출력
# * back : 큐의 가장 뒤에 있는 정수를 출력한다. 만약 큐에 들어있는 정수가 없는 경우엔 -1을 출력
#   - 첫째 줄에 주어지는 명령의 수 N(1<=N<=10,000)이 주어진다. 둘째 줄부터 N개의 줄에는 명령이 하나씩 주어진다. 주어지는 정수는 1보다 크거나 같고, 100,000보다 작거나 같다. 문제에 나와있지 않은 명령이 주어지는 경우는 없다.
#   - 출력해야하는 명령이 주어질 때마다, 한줄에 하나씩 출력

# %%
# 1
class Queue():
  def __init__(self):
    self.queue = []
    self.queue_size = 0

  def push(self, x):
    self.queue.append(x)
    self.queue_size += 1
  def pop(self):
    if self.queue_size==0:
      return -1
    else:
      self.queue_size -= 1
      return self.queue.pop()

  def size(self):
    return self.queue_size

  def empty(self):
    if self.queue_size == 0 :
      return 1
    else:
      return 0

  def front(self):
    if self.queue_size == 0 :
      return -1
    else:
      return self.queue[0]
  
  def back(self):
    if self.queue_size == 0:
      return -1
    else:
      return self.queue[-1]

# %%
N = int(input())
my_queue = Queue()

for i in range(N):
  A = input().split()
  if A[0] == 'push':
    my_queue.push(A[1])
  elif A[0] == 'pop':
    print(my_queue.pop())
  elif A[0] == 'size':
    print(my_queue.size())
  elif A[0] == 'empty':
    print(my_queue.empty())
  elif A[0] == 'front':
    print(my_queue.front())
  elif A[0] == 'back':
    print(my_queue.back())
# Out:
# 15
# push 1
# push 2
# front
# 1
# back
# 2
# size
# 2
# empty
# 0
# pop
# 2
# pop
# 1
# pop
# -1
# size
# 0
# empty
# 1
# pop
# -1
# push 3
# empty
# 0
# front
# 3

# %%
# 2
class Queue():
  def __init__(self, n):
    self.queue = [None for _ in range(n)]
    self.queue_size = 0

  def push(self, x):
    self.queue[queue_size] = x
    self.queue_size += 1
  def pop(self):
    word = self.back()
    if word > -1:



  def size(self):
    return self.queue_size

  def empty(self):
    if self.queue_size == 0 :
      return 1
    else:
      return 0

  def front(self):
    if self.queue_size == 0 :
      return -1
    else:
      return self.queue[0]
  
  def back(self):
    if self.queue_size == 0:
      return -1
    else:
      return self.queue[-1]
