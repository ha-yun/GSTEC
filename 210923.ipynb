# %% [markdown]
# <a href="https://colab.research.google.com/github/ha-yun/GSTEC/blob/main/210923.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - DOCKER SWARM

# %%
# gsweb\docker-compose.yml 파일 생성
version: "3.7"

services:
  django:
    image: ha_django:1
    ports:
    - 8080:8000

# %%
# 터미널 창에 
## aws
ssh -i ha_autumn.pem ubuntu@3.17.130.66

sudo docker swarm init

## google cloud platform
ssh -i ha_gcp deu05230@35.233.226.106

sudo docker swarm init

# %% [markdown]
# 이후에 portainer를 새로고침하면 swarm이 켜지는 상태가 된다!

# %% [markdown]
# ![image.png](data:image/png;base64,...)
