# %% [markdown]
# <a href="https://colab.research.google.com/github/ha-yun/GSTEC/blob/main/210916.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
FROM python:3.9.0

WORKDIR /home/

RUN echo 'abc'

RUN git clone https://github.com/yun-aha/GSWEB.git

WORKDIR /home/GSWEB/

RUN echo "SECRET_KEY=django-insecure-vh!g-^f)eu138bc(2^84w@sbb4m5c5m7t-fpd*##y2ok@w_m8-" > .env

RUN pip install -r requirements.txt

RUN pip install gunicorn

RUN pip install mysqlclient


EXPOSE 8000

CMD ["bash", "-c", "python manage.py collectstatic --noinput --settings=gsweb.settings.deploy && python manage.py migrate --settings=gsweb.settings.deploy && gunicorn --env DJANGO_SETTINGS_MODULE=gsweb.settings.deploy gsweb.wsgi --bind 0.0.0.0:8000"]

# %% [markdown]
# image 업로드! ha_django:4
# container 3개 삭제

# %% [markdown]
# https://hub.docker.com/_/mariadb

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
